# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.cos(1*x))

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.cos(3*x))
